# %% [markdown]
# #### Week 1 -- Python Fundamentals

# %%
name = input("Enter your name: ")
program = input("Enter your program: ")
print("I am ", name, "and I study ", program)
# Out:
# I am  ahmed and I study  BSAI

# %% [markdown]
# #### Why input() returns a string?
# input() always returns the user's input as a string (str), even if the user types a number.
# Because input() reads what you type from the keyboard as text. Python doesn't automatically know whether "18" is supposed to be an integer, decimal, or just text.

# %%
student_count = 40
average_cgpa = 5.5
is_ai_student = True
course_name = "programming for AI"

print(student_count, type(student_count))

print(average_cgpa, type(average_cgpa))

print(is_ai_student, type(is_ai_student))

print(course_name, type(course_name))
# Out:
# 40 <class 'int'>
# 5.5 <class 'float'>
# True <class 'bool'>
# programming for AI <class 'str'>
