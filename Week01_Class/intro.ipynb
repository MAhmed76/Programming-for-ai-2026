# %%
print("Hello AI")
# Out:
# Hello AI

# %% [markdown]
# ### Variables

# %%
age = 20
cgpa = 3.5
name = "Ali"
is_ai_student = True

# %% [markdown]
# ### Dynamic Typing

# %%
value = 10       # int
#print(value)
value = "ten"    # now str
print(value)
# Out:
# ten

# %% [markdown]
# ### Checking a Variable's Type

# %%
print(type(age))
print(type(cgpa))
print(type(name))
print(type(is_ai_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
age = "Ahmed"
cgpa = 20
name = True
is_ai_student = 34.56

print(type(age))
print(type(cgpa))
print(type(name))
print(type(is_ai_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %% [markdown]
# ### Input and Output

# %%
name = input("Enter name:")
print(name)
# Out:
# Ali

# %% [markdown]
# ### Arithmetic Operators in Python

# %%
print(10 + 3)   # Addition → 13
print(10 - 3)   # Subtraction → 7
print(10 * 3)   # Multiplication → 30
print(10 / 3)   # Division → 3.333...
print(10 // 3)  # Floor division → 3
print(10 % 3)   # Remainder (modulus) → 1
print(10 ** 3)  # Exponentiation → 1000
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# ### Comparison Operators

# %%
print(10 == 10)  # Equal to → True
print(10 != 3)   # Not equal to → True
print(10 > 3)    # Greater than → True
print(10 < 3)    # Less than → False
print(10 >= 10)  # Greater than or equal to → True
print(10 <= 3)   # Less than or equal to → False
# Out:
# True
# True
# True
# False
# True
# False

# %% [markdown]
# ### Logical Operators

# %%
print(10 > 5 and 10 < 20)  # Both conditions are True → True
print(10 < 5 or 10 < 20)   # At least one condition is True → True
print(not 10 > 5)           # Reverses True to False → False
# Out:
# True
# True
# False

# %% [markdown]
# ### Assignment Operators

# %%
number = 10      # Assign 10 to number
number += 5      # Same as number = number + 5 → 15
number -= 3      # Same as number = number - 3 → 12
number *= 2      # Same as number = number * 2 → 24
number /= 4      # Same as number = number / 4 → 6.0
number //= 3      # Same as number = number // 3 → 2.0
print(number)
# Out:
# 2.0

# %% [markdown]
# ### Membership Operator

# %%
print("AI" in "Programming for AI")         # Found → True
print("Java" in "Programming for AI")   # Not found → True
# Out:
# True
# False

# %%
numbers = [10, 20, 30, 40]

print(20 in numbers)      # 20 exists in the list → True
print(50 not in numbers)  # 50 does not exist in the list → True
# Out:
# True
# True

# %% [markdown]
# ## Identity Operator

# %%
a = [10, 20]
b = [10, 20]

print(a == b)  # Same values → True
print(a is b)  # Different objects → False
# Out:
# True
# False

# %% [markdown]
# ### Student Marks Calculator

# %%
quiz = float(input("Quiz: "))
assignment = float(input("Assignment: "))
mid = float(input("Mid: "))
final = float(input("Final: "))
 
maximum_marks = 100
total = quiz + assignment + mid + final
percentage = (total / maximum_marks) * 100
print("Total:", total, "/", maximum_marks)
print("Percentage:", percentage)
# Out:
# Total: 80.0 / 100
# Percentage: 80.0

# %%
num = input("Enter a number: ")
num+=5
print(num)
# Out:
# 40

# %% [markdown]
# ### First line of Program

# %%
print("Hello AI")
# Out:
# Hello AI

# %% [markdown]
# ### Variables

# %%
age = 20
cgpa = 3.5
name = "Ali"
is_ai_student = True

# %%
print(age)
print(cgpa)
print(name)
print(is_ai_student)
# Out:
# 20
# 3.5
# Ali
# True

# %% [markdown]
# ### Checking a Variable's Type

# %%
print(type(age))
print(type(cgpa))
print(type(name))
print(type(is_ai_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### Input and Outpu

# %%
name = input("Enter name:")
print(name)
# Out:
# Ali

# %% [markdown]
# ### Arithmetic Operators

# %%
print(10 + 3)   # Addition → 13
print(10 - 3)   # Subtraction → 7
print(10 * 3)   # Multiplication → 30
print(10 / 3)   # Division → 3.333...
print(10 // 3)  # Floor division → 3
print(10 % 3)   # Remainder (modulus) → 1
print(10 ** 3)  # Exponentiation → 1000
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# ### Comparison Operators

# %%
print(10 == 10)  # Equal to → True
print(10 != 3)   # Not equal to → True
print(10 > 3)    # Greater than → True
print(10 < 3)    # Less than → False
print(10 >= 10)  # Greater than or equal to → True
print(10 <= 3)   # Less than or equal to → False
# Out:
# True
# True
# True
# False
# True
# False

# %% [markdown]
# ### Logical Operators

# %%
print(10 > 5 and 10 < 20)  # Both conditions are True → True
print(10 < 5 or 10 < 20)   # At least one condition is True → True
print(not 10 > 5)           # Reverses True to False → False
# Out:
# True
# True
# False

# %% [markdown]
# ### Assignemnt Operators

# %%
number = 10      # Assign 10 to number
number += 5      # Same as number = number + 5 → 15
number -= 3      # Same as number = number - 3 → 12
number *= 2      # Same as number = number * 2 → 24
number /= 4      # Same as number = number / 4 → 6.0

# %% [markdown]
# ### Membership Operators

# %%
print("AI" in "Programming for AI")         # Found → True
print("Java" not in "Programming for AI")   # Not found → True
# Out:
# True
# True

# %%
numbers = [10, 20, 30, 40]

print(20 in numbers)      # 20 exists in the list → True
print(50 not in numbers)  # 50 does not exist in the list → True
# Out:
# True
# True

# %% [markdown]
# ### Identity Operator

# %%
a = [10, 20]
b = [10, 20]

print(a == b)  # Same values → True
print(a is b)  # Different objects → False
# Out:
# True
# False

# %% [markdown]
# ### Student Marks Calculator

# %%
quiz = float(input("Quiz: "))
assignment = float(input("Assignment: "))
mid = float(input("Mid: "))
final = float(input("Final: "))
 
maximum_marks = 100
total = quiz + assignment + mid + final
percentage = (total / maximum_marks) * 100
print("Total:", total, "/", maximum_marks)
print("Percentage:", percentage)
# Out:
# Total: 79.0 / 100
# Percentage: 79.0
